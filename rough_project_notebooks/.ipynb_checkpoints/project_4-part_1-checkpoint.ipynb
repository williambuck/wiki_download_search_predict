# %% [markdown]
# # PROJECT 4: Semantic Search
#
# ## The Task
# The objective of this assignment is to engineer a novel wikipedia search engine using what you've learned about data collection, infrastructure, and natural language processing.
#
# The task has two **required sections:**
# - Data collection
# - Search algorithm development
#
# And one **optional section:**
#   - Predictive modeling
#
# ![](http://interactive.blockdiag.com/image?compression=deflate&encoding=base64&src=eJxdjrsOwjAMRXe-wlsmRhaQkDoiMSDxBW5slahtHDmGCiH-nfQxtKy-59zruhPfUsAGPjsA56XvMdIRSIbYCZKD_RncENqQuGBQ3S7TidCwxsynjZUZ1T8m4HqvJlXZnhrBJMHBbWlTDHEeSFravYUXQy_E3TKrwbioMKb5z16UmRxfXZurVY_GjegbhqJIjaXm-wNmzE4W)
#
# ### Part 1 -- Collection (required)
#
# We want you to query the wikipedia API and **collect all of the articles** under the following wikipedia categories:
#
# * [Machine Learning](https://en.wikipedia.org/wiki/Category:Machine_learning)
# * [Business Software](https://en.wikipedia.org/wiki/Category:Business_software)
#
# The raw page text and its category information should be written to a collection on a Mongo server running on a dedicated AWS instance.
#
# We want your code to be modular enough that any valid category from Wikipedia can be queried by your code. You are encouraged to exploit this modularity to pull additional wikipedia categories beyond ML and Business Software. As always, the more data the better.
#
# **Note:** Both "Machine Learning" and "Business Software" contain a heirarchy of nested sub-categories. Make sure that you pull every single page within each parent category, not just those directly beneath them. Take time to explore wikipedia's organization structure. It is up to you if you want to model this heirarchy anywhere within Mongo, otherwise flatten it by only recording the parent category associated with each page.
#
# **optional**
# Make it so that your code can be run via a python script e.g.
#
# ```bash
# $ docker run --rm -v $(pwd):/home/jovyan jupyter/scipy-notebook python download.py #SOME_CATEGORY#
# ```
# This docker command starts a disposable scipy-notebook container for one-time use to run your script, `download.py`. Where `#SOME_CATEGORY#` is the wikipedia category to be downloaded. Read about passing arguments to python scripts here: https://docs.python.org/3/library/sys.html.
#
# **optional**
# Make it so that your code can query nested sub-categories e.g.
#
# ```bash
# $ docker run --rm -v $(pwd):/home/jovyan jupyter/scipy-notebook python download.py #SOME_CATEGORY# #NESTING_LEVEL#
# ```
#
# ### Part 2 -- Search (required)
#
# Use Latent Semantic Analysis to search your pages. Given a search query, find the top 5 related articles to the search query. SVD and cosine similarity are a good place to start.
#
# **optional**
# Make it so that your code can be run via a python script e.g.
#
# ```bash
# $ docker run --rm -v $(pwd):/home/jovyan jupyter/scipy-notebook python search.py #SOME_TERM#
# ```
#
# ### Part 3 -- Predictive Model (optional)
#
# In this part, we want you to build a predictive model from the data you've just indexed. Specifically, when a new article from wikipedia comes along, we would like to be able to predict what category the article should fall into. We expect a training script of some sort that is runnable and will estimate a model.
#
# Make it so that your code can be run via a python script e.g.
#
# ```bash
# $ docker run --rm -v $(pwd):/home/jovyan jupyter/scipy-notebook python train.py
# ```
#
# Finally, you should be able to pass the url of a wikipedia page and it will generate a prediction for the best category for that page, along with a probability of that being the correct category.
#
# Make it so that your code can be run via a python script e.g.
#
# ```bash
# $ docker run --rm -v $(pwd):/home/jovyan jupyter/scipy-notebook python predict.py #URL#
# ```
#
# ## Infrastructure
#
# We recommend that you run a MongDB server on a dedicated t2.micro instance. Feel free to run your Jupyter environment either on another instance or locally.

# %%
import re
import requests
import pandas as pd
import numpy as np
import pymongo

from string import punctuation
from bs4 import BeautifulSoup

client = pymongo.MongoClient('35.163.182.105', 27016)

# %%
# %run download.py

# %%
client.database_names()
# Out:
# ['admin',
#  'business_software_wiki_db',
#  'local',
#  'test',
#  'test_wiki_db',
#  'wiki_content_db']

# %%
client.business_software_wiki_db.collection_names()
# Out:
# []

# %% [markdown]
# ### Business Software Category

# %%
busi_soft_mongo = store_wiki_contents_in_mongo('business_software_wiki_db')

# %%
# %time busi_soft_mongo.get_all_page_contents_from_category('Business software', overwrite=True, )
# Out:
# CPU times: user 57.7 s, sys: 4.71 s, total: 1min 2s
# Wall time: 16min 56s

# %%
client.database_names()
# Out:
# ['admin',
#  'business_software_wiki_db',
#  'local',
#  'test',
#  'test_wiki_db',
#  'wiki_content_db']

# %%
class collection_merger_df_maker():
    
    my_df = pd.DataFrame()
    
#     def __init__(self):
        
#         self.my_df = pd.DataFrame()
    
    def make_collection_df(self, database, collection):
        return pd.DataFrame(list(client[database][collection].find()))

    def merge_collections(self, database):
        collection_list = [x for x in client[database].collection_names()]
        for col in collection_list:
            temp_df = self.make_collection_df(database, col)
            self.my_df = pd.concat([self.my_df, temp_df], ignore_index=True)
        return self.my_df

# %%
cmdm = collection_merger_df_maker()

# %%
bs_df = cmdm.merge_collections('business_software_wiki_db')

# %%
bs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1875 entries, 0 to 1874
# Data columns (total 6 columns):
# _id                1875 non-null object
# category           1875 non-null object
# content            1875 non-null object
# page_id            1875 non-null int64
# parent_category    1875 non-null object
# title              1875 non-null object
# dtypes: int64(1), object(5)
# memory usage: 88.0+ KB

# %%
lengths = []
for x in bs_collection_list:
    lengths.append(len(cmdm.make_collection_df('business_software_wiki_db', x)))
    
sum(lengths)
# Out:
# 1892

# %%
test_mongo = store_wiki_contents_in_mongo('test_wiki_db')
# %time test_mongo.get_all_page_contents_from_category('Business software', overwrite=True, nesting_level=1)

# %%
len(pd.DataFrame(list(client.test_wiki_db.Business_software_wiki_content_collection.find())))
# Out:
# 827

# %% [markdown]
# ### Machine Learning Category

# %%
wiki_content_db = client.wiki_content_db
wiki_coll_ref = wiki_content_db.machine_learning_wiki_content_collection

# %%
# %time get_all_page_contents_from_category('Machine learning', overwrite=True)
# Out:
# CPU times: user 50.8 s, sys: 6.54 s, total: 57.3 s
# Wall time: 17min 10s

# %%
len(wiki_content_db.collection_names())
# Out:
# 49

# %%
wiki_content_db.collection_names()

# %%
pd.DataFrame(list(wiki_content_db.machine_learning_wiki_content_collection.find()))
# Out:
#                           _id          category  \
# 0    5a0d36fb830fdb7bcde23811  machine learning
# 1    5a0d36fb830fdb7bcde23812  machine learning
# 2    5a0d36fc830fdb7bcde23813  machine learning
# 3    5a0d36fd830fdb7bcde23814  machine learning
# 4    5a0d36fd830fdb7bcde23815  machine learning
# 5    5a0d36fe830fdb7bcde23816  machine learning
# 6    5a0d36fe830fdb7bcde23817  machine learning
# 7    5a0d36ff830fdb7bcde23818  machine learning
# 8    5a0d3700830fdb7bcde23819  machine learning
# 9    5a0d3700830fdb7bcde2381a  machine learning
# 10   5a0d3701830fdb7bcde2381b  machine learning
# 11   5a0d3702830fdb7bcde2381c  machine learning
# 12   5a0d3702830fdb7bcde2381d  machine learning
# 13   5a0d3703830fdb7bcde2381e  machine learning
# 14   5a0d3703830fdb7bcde2381f  machine learning
# 15   5a0d3704830fdb7bcde23820  machine learning
# 16   5a0d3704830fdb7bcde23821  machine learning
# 17   5a0d3705830fdb7bcde23822  machine learning
# 18   5a0d3705830fdb7bcde23823  machine learning
# 19   5a0d3706830fdb7bcde23824  machine learning
# 20   5a0d3706830fdb7bcde23825  machine learning
# 21   5a0d3707830fdb7bcde23826  machine learning
# 22   5a0d3708830fdb7bcde23827  machine learning
# 23   5a0d3708830fdb7bcde23828  machine learning
# 24   5a0d3709830fdb7bcde23829  machine learning
# 25   5a0d3709830fdb7bcde2382a  machine learning
# 26   5a0d370a830fdb7bcde2382b  machine learning
# 27   5a0d370a830fdb7bcde2382c  machine learning
# 28   5a0d370b830fdb7bcde2382d  machine learning
# 29   5a0d370c830fdb7bcde2382e  machine learning
# ..                        ...               ...
# 198  5a0d376c830fdb7bcde238d7  machine learning
# 199  5a0d376c830fdb7bcde238d8  machine learning
# 200  5a0d376d830fdb7bcde238d9  machine learning
# 201  5a0d376d830fdb7bcde238da  machine learning
# 202  5a0d376e830fdb7bcde238db  machine learning
# 203  5a0d376e830fdb7bcde238dc  machine learning
# 204  5a0d376f830fdb7bcde238dd  machine learning
# 205  5a0d3770830fdb7bcde238de  machine learning
# 206  5a0d3770830fdb7bcde238df  machine learning
# 207  5a0d3771830fdb7bcde238e0  machine learning
# 208  5a0d3771830fdb7bcde238e1  machine learning
# 209  5a0d3772830fdb7bcde238e2  machine learning
# 210  5a0d3772830fdb7bcde238e3  machine learning
# 211  5a0d3773830fdb7bcde238e4  machine learning
# 212  5a0d3773830fdb7bcde238e5  machine learning
# 213  5a0d3774830fdb7bcde238e6  machine learning
# 214  5a0d3774830fdb7bcde238e7  machine learning
# 215  5a0d3775830fdb7bcde238e8  machine learning
# 216  5a0d3775830fdb7bcde238e9  machine learning
# 217  5a0d3776830fdb7bcde238ea  machine learning
# 218  5a0d3776830fdb7bcde238eb  machine learning
# 219  5a0d3777830fdb7bcde238ec  machine learning
# 220  5a0d3778830fdb7bcde238ed  machine learning
# 221  5a0d3778830fdb7bcde238ee  machine learning
# 222  5a0d3779830fdb7bcde238ef  machine learning
# 223  5a0d3779830fdb7bcde238f0  machine learning
# 224  5a0d377a830fdb7bcde238f1  machine learning
# 225  5a0d377a830fdb7bcde238f2  machine learning
# 226  5a0d377b830fdb7bcde238f3  machine learning
# 227  5a0d377b830fdb7bcde238f4  machine learning
#
#                                                content   page_id  \
# 0    Data exploration is an approach similar to ini...  43385931
# 1    These datasets are used for machinelearning re...  49082762
# 2    Machine learning is a field of computer scienc...    233488
# 3    The following outline is provided as an overvi...  53587467
# 4    The accuracy paradox for predictive analytics ...   3771060
# 5    Action model learning sometimes abbreviated ac...  43808044
# 6    Active learning is a special case of semisuper...  28801798
# 7    Adversarial machine learning is a research fie...  45049676
# 8    AIVA Artificial Intelligence Virtual Artist is...  52642349
# 9    AIXI ai̯k͡siː is a theoretical mathematical fo...  30511763
# 10   Algorithm selection sometimes also called peri...  50773876
# 11   Algorithmic inference gathers new developments...  20890511
# 12   AlphaGo is a computer program that plays the b...  49242352
# 13   AlphaGo Zero is a version of DeepMinds Go soft...  55572262
# 14   Apprenticeship learning or apprenticeship via ...  19463198
# 15   The bagofwords model is a simplifying represen...  14003441
# 16   In computer science a ball tree balltree or me...  31877832
# 17   In probability and statistics base rate genera...   9732182
# 18   In machine learning kernel methods arise from ...  35867897
# 19   Bayesian optimization is a sequential design s...  40973765
# 20   Bayesian structural time series BSTS model is ...  50211107
# 21   In statistics and machine learning the bias–va...  40678189
# 22   BigDL is a deep learning framework developed a...  55075082
# 23   Binary or binomial classification is the task ...    205393
# 24   Bing Predicts is a prediction engine developed...  50646178
# 25   A Bongard problem is a kind of puzzle invented...   1191936
# 26   The Bradley–Terry model is a probability model...  44439173
# 27   Caffe is a deep learning framework originally ...  53631046
# 28   Catastrophic interference also known as catast...  39182554
# 29   Category utility is a measure of category good...   8964665
# ..                                                 ...       ...
# 198                                                     33547387
# 199  This category are for articles about artificia...  42936114
# 200                                                      1718975
# 201  This category is about statistical classificat...   1991254
# 202                                                     22532673
# 203                                                     34310097
# 204  Academic conferences related to artificial int...  12932492
# 205  y  Some products in CategoryData analysis soft...  33542714
# 206                                                     42320378
# 207                                                     29549713
# 208  Ensemble learning is a type of machine learnin...   3985352
# 209  An evolutionary algorithm EA is a heuristic op...    754055
# 210  Genetic programming GP is an automated methodo...   3061615
# 211                                                     29003796
# 212  This page lists categories and articles relate...  12535256
# 213                                                     20924581
# 214  Learningbased methods in computer vision make ...  19314112
# 215  Not to be confused with Logistic regression mo...  36407925
# 216                                                     28004586
# 217                                                     33547228
# 218  Note This portal navigation can be placed on a...  44943481
# 219                Category for machine learning tasks  47991509
# 220                                                     24059390
# 221             Researchers who study machine learning   3832584
# 222                                                     52763829
# 223                                                     11737376
# 224                                                     40149461
# 225                                                     52763867
# 226                                                     31176997
# 227                                                     52763828
#
#     parent_category                                              title
# 0              none                                   Data exploration
# 1              none     List of datasets for machine learning research
# 2              none                                   Machine learning
# 3              none                        Outline of machine learning
# 4              none                                   Accuracy paradox
# 5              none                              Action model learning
# 6              none                 Active learning (machine learning)
# 7              none                       Adversarial machine learning
# 8              none                                               AIVA
# 9              none                                               AIXI
# 10             none                                Algorithm selection
# 11             none                              Algorithmic inference
# 12             none                                            AlphaGo
# 13             none                                       AlphaGo Zero
# 14             none                            Apprenticeship learning
# 15             none                                 Bag-of-words model
# 16             none                                          Ball tree
# 17             none                                          Base rate
# 18             none   Bayesian interpretation of kernel regularization
# 19             none                              Bayesian optimization
# 20             none                    Bayesian structural time series
# 21             none                             Bias–variance tradeoff
# 22             none                                              BigDL
# 23             none                              Binary classification
# 24             none                                      Bing Predicts
# 25             none                                    Bongard problem
# 26             none                                Bradley–Terry model
# 27             none                                   Caffe (software)
# 28             none                          Catastrophic interference
# 29             none                                   Category utility
# ..              ...                                                ...
# 198            none                  Category:Applied machine learning
# 199            none                Category:Artificial neural networks
# 200            none                         Category:Bayesian networks
# 201            none                 Category:Classification algorithms
# 202            none                          Category:Cluster analysis
# 203            none             Category:Computational learning theory
# 204            none       Category:Artificial intelligence conferences
# 205            none  Category:Data mining and machine learning soft...
# 206            none              Category:Datasets in machine learning
# 207            none                       Category:Dimension reduction
# 208            none                         Category:Ensemble learning
# 209            none                   Category:Evolutionary algorithms
# 210            none                       Category:Genetic programming
# 211            none               Category:Inductive logic programming
# 212            none       Category:Kernel methods for machine learning
# 213            none                    Category:Latent variable models
# 214            none               Category:Learning in computer vision
# 215            none                         Category:Log-linear models
# 216            none                            Category:Loss functions
# 217            none               Category:Machine learning algorithms
# 218            none                   Category:Machine learning portal
# 219            none                     Category:Machine learning task
# 220            none                             Category:Markov models
# 221            none              Category:Machine learning researchers
# 222            none                   Category:Semisupervised learning
# 223            none   Category:Statistical natural language processing
# 224            none                     Category:Structured prediction
# 225            none                       Category:Supervised learning
# 226            none                   Category:Support vector machines
# 227            none                     Category:Unsupervised learning
#
# [228 rows x 6 columns]

# %%
client.database_names()
# Out:
# ['admin', 'local', 'test', 'wiki_content_db']

# %%
for x in sorted(wiki_content_db.collection_names()):
    if len(list(wiki_content_db[x].find({'content':''}))) >= 1:
        print('{:42}'.format(x[:-24]), len(list(wiki_content_db[x].find({'content':''}))))
# Out:
# Artificial_neural_networks                 2
# Classification_algorithms                  1
# Cluster_analysis                           1
# Data_mining_and_machine_learning_software  1
# Decision_trees                             1
# Dimension_reduction                        1
# Evolutionary_algorithms                    4
# Genetic_algorithms                         6
# Graphical_models                           2
# Kernel_methods_for_machine_learning        1
# Latent_variable_models                     2
# Markov_models                              2
# Statistical_natural_language_processing    1
# Structured_prediction                      1
# machine_learning                           17

# %%
### saving this for later, code is to rename a db

# client.admin.command('copydb',
#                      fromdb='source_db_name',
#                      todb='target_db_name')

# client.drop_database('<DBNAME>')
